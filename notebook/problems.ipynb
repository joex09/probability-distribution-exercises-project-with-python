# %% [markdown]
# # Probability Distribution Problems

# %% [markdown]
# **Binomial Distribution**
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment, for example, when you flip a coin it can by either Head or Tails.

# %%
# Probability functions, density and distribution

def dbinom(x,size,prob=0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    from scipy.stats import binom
    result=binom.pmf(k=x,n=size,p=prob,loc=0)
    return result

def pbinom(q,size,prob=0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    from scipy.stats import binom
    result=binom.cdf(k=q,n=size,p=prob,loc=0)
    return result

def qbinom(p, size, prob=0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    from scipy.stats import binom
    result=binom.ppf(q=p,n=size,p=prob,loc=0)
    return result

def rbinom(n,size,prob=0.5):
    """
    Generates random variables from the binomial distribution
    """
    from scipy.stats import binom
    result=binom.rvs(n=size,p=prob,size=n)
    return result

# %%
dbinom(2, size = 10, prob = 0.2) #Probability that a binomial (10,0.2) takes the value 2,
pbinom(2, size = 10, prob = 0.2) #Probability that a binomial (10,0.2) will take a value less than 2
qbinom(0.9, size = 10, prob = 0.2) # what value of a binomial (10,0.2) has a cumulative probability of 0.9?
rbinom(2000, size = 10, prob = 0.2) # generate 2000 random values from a binomial distribution (10,0.2)
# Out:
# array([1, 1, 1, ..., 1, 4, 2])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Discrete distributions
xs = np.arange( 1, 11 )
ys = dbinom(xs,size=10,prob=0.5) # compute the shape of the distribution
plt.plot( xs, ys, 'o' )   # plot circles...
plt.vlines( xs, 0, ys )   # ...and lines
plt.ylim( bottom=0 )      # ensure sensible bottom border
plt.title('Probability function binomial distribution')
plt.show()

# %% [markdown]
# Exercise 1: Create the same functions but for the normal and uniform distribution.

# %%
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Running cells with 'Python 2.7.18 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python2 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Normal distribution
# Probability functions, density and distribution

def dnorm(x,mean=0,sd=1):
    """
    Measures probability density function (pdf) of the normal distribution
    """
    from scipy.stats import norm
    result=norm.pdf(x,loc=mean,scale=sd)
    return result

def pnorm(x,mean=0,sd=1):
    """
    Calculates the cumulative of the normal distribution
    """
    from scipy.stats import norm
    result=norm.cdf(x,loc=mean,scale=sd)
    return result

def qnorm(p, mean=0,sd=1):
    """
    Takes the probability value and returns cumulative value corresponding to probability value of the distribution
    """
    from scipy.stats import norm
    result=norm.ppf(q=p,loc=mean,scale=sd)
    return result

def rnorm(n,mean=0,sd=1):
    """
    Generates random variables from the normal distribution
    """
    from scipy.stats import norm
    result=norm.rvs(size=n,loc=mean,scale=sd)
    return result
# Out:
# Running cells with 'Python 2.7.18 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python2 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Normal density function

x = np.arange(-6, 6, 0.1)   
y = dnorm(x)
   
plt.plot(x, y) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb Cell 9 in <cell line: 3>()
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # Normal density function
# ----> <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> x = np.arange(-6, 6, 0.1)
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> y = dnorm(x)
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> plt.plot(x, y)
#
# NameError: name 'np' is not defined

# %%
# Normal cumulative distribution function

x = np.arange(-10, 10, 0.1)
   
y = pnorm(x)
   
plt.plot(x, y) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb Cell 10 in <cell line: 3>()
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # Normal cumulative distribution function
# ----> <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> x = np.arange(-10, 10, 0.1)
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> y = pnorm(x)
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> plt.plot(x, y)
#
# NameError: name 'np' is not defined

# %%
# Normal ppf function

x = np.arange(0, 1, 0.01) # range of probabilities
   
y = qnorm(x)
   
plt.plot(x, y) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb Cell 11 in <cell line: 3>()
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # Normal ppf function
# ----> <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> x = np.arange(0, 1, 0.01) # range of probabilities
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> y = qnorm(x)
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> plt.plot(x, y)
#
# NameError: name 'np' is not defined

# %%
# generate 1000 random values from a normal distribution (0,1)

y = rnorm(1000)

#creating bin
bin = np.arange(-4,4,0.1)  

plt.hist(y, bins=bin, edgecolor='blue') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb Cell 12 in <cell line: 3>()
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # generate 1000 random values from a normal distribution (0,1)
# ----> <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> y = rnorm(1000)
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> #creating bin
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> bin = np.arange(-4,4,0.1)
#
# NameError: name 'rnorm' is not defined

# %%
print("Normal(0,1)")
print()
print("P(X<=0):", pnorm(0))
print("Cumulative value at 50% probability:", qnorm(0.5))
# Out:
# Normal(0,1)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb Cell 13 in <cell line: 3>()
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> print("Normal(0,1)")
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> print()
# ----> <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> print("P(X<=0):", pnorm(0))
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> print("Cumulative value at 50% probability:", qnorm(0.5))
#
# NameError: name 'pnorm' is not defined

# %%
# uniform

def point_estimate_uniform(x, start=0, end=1):
    """
    Calculates the point estimate of the uniform distribution
    """
    result=uniform.pdf(x, loc=start, scale=end-start)
    return result

# formerly known as puniform
def cumulative_estimate_uniform(x, start=0, end=1):
    """
    Calculates the cumulative of the normal distribution
    """
    result=uniform.cdf(x, loc=start, scale=end-start)
    return result

# formerly known as quniform
def quantile_uniform(probability, start=0, end=1):
    """
    Calculates the quantile function from the uniform distribution
    """
    result=norm.ppf(q=probability, loc=start, scale=end-start)
    return result

# formerly known as runiform
# formerly known as runiform
def random_uniform(size=1, start=0, end=1):
    """
    Generates random variables from the uniform distribution
    """
    result=uniform.rvs(loc=start, scale=end-start, size=size)
    return result

# %%
print()
print()
print(f"Call to point_estimate_uniform: {point_estimate_uniform(x=0.4, start=-1, end=1)}")
print(f"Call to cumulative_estimate_uniform: {cumulative_estimate_uniform(x=0.4, start=-1, end=1)}")
print(f"Call to quantile_uniform: {quantile_uniform(probability=0.80, start=-1, end=1)}")
print(f"Call to random_uniform: {random_uniform(size=10, start=-1, end=1)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb Cell 15 in <cell line: 3>()
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> print()
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> print()
# ----> <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> print(f"Call to point_estimate_uniform: {point_estimate_uniform(x=0.4, start=-1, end=1)}")
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> print(f"Call to cumulative_estimate_uniform: {cumulative_estimate_uniform(x=0.4, start=-1, end=1)}")
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> print(f"Call to quantile_uniform: {quantile_uniform(probability=0.80, start=-1, end=1)}")
#
# /workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb Cell 15 in point_estimate_uniform(x, start, end)
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> def point_estimate_uniform(x, start=0, end=1):
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     """
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     Calculates the point estimate of the uniform distribution
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     """
# ----> <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     result=uniform.pdf(x, loc=start, scale=end-start)
#       <a href='vscode-notebook-cell://joex09-probabilitydistr-o4zgobx1sgw.ws-us62.gitpod.io/workspace/probability-distribution-exercises-project-with-python/notebook/problems.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     return result
#
# NameError: name 'uniform' is not defined
